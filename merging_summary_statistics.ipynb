# %%
import pandas as pd
import os

def onefile(directory):
    dataframes = []

    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            try:
                df = pd.read_csv(file_path)
                dataframes.append(df)
            except Exception as e:
                print(f"Error loading {filename}: {e}")

    combined_df = pd.concat(dataframes, ignore_index=True)
    return combined_df
# Out:
# C:\Anaconda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # color per user

# %%
colorperuser = onefile(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\color user')

# %%
colorperuser
# Out:
#                                                        user  \
# 0         ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...
# 1         +++9mkCyhbuOFF5ZusNO7JGW63zMmkWVwoqOqM6D9/9rxK...
# 2         +++DHgz9FIWS2Ux/9geWfi2uf4+trwOcs2MJlGPw/ZyFkT...
# 3         +++DVJPUzMUiQybH5SaWeO15S5jKuyW1AYw0L7HKM9bx4d...
# 4         +++IG2b8dqn9TcyyJa/ngp9XDr7tjfVX9kraYN4JtQyulv...
# ...                                                     ...
# 16640535  zzzMzrlVdEX2JBEKmtRQmsAW2nFC7avF79rBqLZYcDmlHp...
# 16640536  zzzcjNI4Nfcit49Vkh4QycWDAjCy2ML+3HeCeIWF30h5lH...
# 16640537  zzzf8WipWHVb2PD7ZggIVQoym4tSicnFpn38qpUpxpUdD1...
# 16640538  zzzilJa7+m/C79SuvQcHvD4xfbN0dDfBlIFoSnHZr0GYUi...
# 16640539  zzzx8RjteNN3ctg2wCJKoHujFjipe04ohdyKyLE4rvZWea...
#
#                                                    0
# 0                       #3690EA#FFA800#000000#000000
# 1                              #000000#000000#000000
# 2         #FF4500#FF4500#FF4500#B44AC0#000000#3690EA
# ...

# %%
colorperuser.rename(columns={'0': 'colors'}, inplace=True)

# %%
color_per_user_final = colorperuser.groupby('user')['colors'].apply(''.join).reset_index()

# %%
color_per_user_final['unique_color_count'] = color_per_user_final['colors'].apply(lambda x: len(set(filter(None, x.split('#')))))

# %%
color_per_user_final
# Out:
#                                                       user  \
# 0        ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...
# 1        +++2YMNQROwh54UiQEYv6iz5yQdEr8uXrZ2EcTkipRbtJ+...
# 2        +++2ny7CcancFxNL6HI+hcDiqXGepL+zGk9n9wfz8tNjCA...
# 3        +++5DPynrKmnxpZ5nTRQ3tH/bHtaN90XCoL0R8e5a3mLuo...
# 4        +++8f06xnBjeWJ3728FQUjrV5mg3eJRHZra2yYWSySguD7...
# ...                                                    ...
# 8520735  zzzjfV1HB0gkG+okqEPrPMkX27yhc8p2qv65lYVEXrShF+...
# 8520736  zzzrqJ2aW2HA7cFdwVYBHBzvVFaY1j8AF8TMBT7NEORdQm...
# 8520737  zzztnsHs8wXafNsiw7ldFCrJT2iFdz8/IpP9dTNp3jx+6x...
# 8520738  zzzx8RjteNN3ctg2wCJKoHujFjipe04ohdyKyLE4rvZWea...
# 8520739  zzzyKoWFuXZ5fG46Fr5izLfUAw6H7BTx/by2MvDWEryfO2...
#
#                                                     colors  unique_color_count
# 0        #3690EA#FFA800#000000#000000#898D90#FFFFFF#51E...                   6
# 1                                                  #FF4500                   1
# ...

# %% [markdown]
# # cord per user

# %%
 coordusers= onefile(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\coorusers')

# %%
coordusers
# Out:
#                                                        user  \
# 0         ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...
# 1         +++9mkCyhbuOFF5ZusNO7JGW63zMmkWVwoqOqM6D9/9rxK...
# 2         +++DHgz9FIWS2Ux/9geWfi2uf4+trwOcs2MJlGPw/ZyFkT...
# 3         +++DVJPUzMUiQybH5SaWeO15S5jKuyW1AYw0L7HKM9bx4d...
# 4         +++IG2b8dqn9TcyyJa/ngp9XDr7tjfVX9kraYN4JtQyulv...
# ...                                                     ...
# 16640535  zzzMzrlVdEX2JBEKmtRQmsAW2nFC7avF79rBqLZYcDmlHp...
# 16640536  zzzcjNI4Nfcit49Vkh4QycWDAjCy2ML+3HeCeIWF30h5lH...
# 16640537  zzzf8WipWHVb2PD7ZggIVQoym4tSicnFpn38qpUpxpUdD1...
# 16640538  zzzilJa7+m/C79SuvQcHvD4xfbN0dDfBlIFoSnHZr0GYUi...
# 16640539  zzzx8RjteNN3ctg2wCJKoHujFjipe04ohdyKyLE4rvZWea...
#
#                                                      0
# 0                        445,-495179,460194,367785,-43
# 1                                 141,71-222,97348,200
# 2         -236,-35-5,210109,-132-340,466786,261665,365
# ...

# %%
coordusers.rename(columns={'0': 'coordinates'}, inplace=True)

# %%
cord_user_final = coordusers.groupby('user')['coordinates'].apply(lambda x: '//'.join(x)).reset_index()

# %%
cord_user_final
# Out:
#                                                       user  \
# 0        ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...
# 1        +++2YMNQROwh54UiQEYv6iz5yQdEr8uXrZ2EcTkipRbtJ+...
# 2        +++2ny7CcancFxNL6HI+hcDiqXGepL+zGk9n9wfz8tNjCA...
# 3        +++5DPynrKmnxpZ5nTRQ3tH/bHtaN90XCoL0R8e5a3mLuo...
# 4        +++8f06xnBjeWJ3728FQUjrV5mg3eJRHZra2yYWSySguD7...
# ...                                                    ...
# 8520735  zzzjfV1HB0gkG+okqEPrPMkX27yhc8p2qv65lYVEXrShF+...
# 8520736  zzzrqJ2aW2HA7cFdwVYBHBzvVFaY1j8AF8TMBT7NEORdQm...
# 8520737  zzztnsHs8wXafNsiw7ldFCrJT2iFdz8/IpP9dTNp3jx+6x...
# 8520738  zzzx8RjteNN3ctg2wCJKoHujFjipe04ohdyKyLE4rvZWea...
# 8520739  zzzyKoWFuXZ5fG46Fr5izLfUAw6H7BTx/by2MvDWEryfO2...
#
#                                                coordinates
# 0        445,-495179,460194,367785,-43//793,-97815,-90/...
# 1                                                 731,-368
# 2        915,470//919,674986,652911,524922,483971,65591...
# ...

# %% [markdown]
# # unique coord user

# %%
uniquecoorduser = onefile(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\unique corduser')

# %%
uniquecoorduser.head(5)
# Out:
#                                                 user     0
# 0  ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...   4.0
# 1  +++9mkCyhbuOFF5ZusNO7JGW63zMmkWVwoqOqM6D9/9rxK...  21.0
# 2  +++DHgz9FIWS2Ux/9geWfi2uf4+trwOcs2MJlGPw/ZyFkT...   8.0
# 3  +++DVJPUzMUiQybH5SaWeO15S5jKuyW1AYw0L7HKM9bx4d...   1.0
# 4  +++IG2b8dqn9TcyyJa/ngp9XDr7tjfVX9kraYN4JtQyulv...   6.0

# %%
uniquecoorduser.rename(columns={'0': 'unique_cord'}, inplace=True)

# %%
unique_cord_user_final = uniquecoorduser.groupby('user',as_index = False)['unique_cord'].sum()

# %%
unique_cord_user_final
# Out:
#                                                       user  unique_cord
# 0        ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...          8.0
# 1        +++2YMNQROwh54UiQEYv6iz5yQdEr8uXrZ2EcTkipRbtJ+...          1.0
# 2        +++2ny7CcancFxNL6HI+hcDiqXGepL+zGk9n9wfz8tNjCA...         21.0
# 3        +++5DPynrKmnxpZ5nTRQ3tH/bHtaN90XCoL0R8e5a3mLuo...          3.0
# 4        +++8f06xnBjeWJ3728FQUjrV5mg3eJRHZra2yYWSySguD7...         39.0
# ...                                                    ...          ...
# 8520735  zzzjfV1HB0gkG+okqEPrPMkX27yhc8p2qv65lYVEXrShF+...          3.0
# 8520736  zzzrqJ2aW2HA7cFdwVYBHBzvVFaY1j8AF8TMBT7NEORdQm...         13.0
# 8520737  zzztnsHs8wXafNsiw7ldFCrJT2iFdz8/IpP9dTNp3jx+6x...          2.0
# 8520738  zzzx8RjteNN3ctg2wCJKoHujFjipe04ohdyKyLE4rvZWea...         56.0
# 8520739  zzzyKoWFuXZ5fG46Fr5izLfUAw6H7BTx/by2MvDWEryfO2...          1.0
#
# [8520740 rows x 2 columns]

# %% [markdown]
# # unique color user

# %%
#uniquecoloruser = onefile(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\uniquecoloruser')

# %%
#uniquecoloruser.head(5)

# %%
#uniquecoloruser.rename(columns={'0': 'unique_colors'}, inplace=True)

# %%
#unique_color_user_final = uniquecoloruser.groupby('user',as_index = False)['unique_colors'].sum()

# %%
#unique_color_user_final

# %% [markdown]
# # pix per user

# %%
pixperuser = onefile(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\pixperuser')

# %%
pixperuser.rename(columns={'0': 'tot_pixels'}, inplace=True)

# %%
pix_per_user_final = pixperuser.groupby('user', as_index=False)['tot_pixels'].sum()

# %%
pix_per_user_final.sort_values(by = 'tot_pixels')
# Out:
#                                                                                              user  \
# 8520739  zzzyKoWFuXZ5fG46Fr5izLfUAw6H7BTx/by2MvDWEryfO280rcaFRsXadOY5Z0x2mjgfpBKVFARg4yZbvnxWfw==
# 6390998  k+AV67YTrBzvvZfwxRFV4kVix0+o/+K3IDeU97IWsOYWxFQjxGv1V9L3fXNPYNsxZI41kTzji+AA8cDIFmf/ew==
# 2570254  HGMulj/g/5GFMOSLO+kXCTpwxKI4wu0Rz82EpSm5lgCy8zDi2EX0OGKdivIFJftTvZsJyOSiDkerh9sYMHJyaw==
# 2570256  HGN+r2kwNF+U2EVY4evOdQGr8DoDu4pCzm/EyvdSbaCWbnjaFTJH+9fJKzhAoqTiKb9fvjmNY++d4CiQVzaE9w==
# 6390996  k+APQNq23qscj/RfMMg1fovmg5LZKsKKSw+7G8eHTY21b4N05YUo7h8eBPj+Y3O8vZQzjQ97+YLlgmYnuFnouA==
# ...                                                                                           ...
# 5189696  ay5U7RmL4QAj/p06ODdMbVh7lc1LqvfZHMFaU6BNIzcIVD1QSn1gerRGhCtGMqewNZKwpcF/LyWn61YF2r3ZDQ==
# 5255788  bRwFe1qJhazPc7ur8S6hK8U0J0iPFVap53hfqoo9lxMebVE7a+ipl2x8FUkL3oRtUjW+0JImeTYb2XQAEq5rjw==
# ...

# %% [markdown]
# # pix per second

# %%
pixpersec = onefile(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\pixpersec')

# %%
pixpersec.head(5)
# Out:
#                      timestamp    0
# 0  2023-07-20 13:00:26.088 UTC  1.0
# 1  2023-07-20 13:00:43.658 UTC  1.0
# 2  2023-07-20 13:00:43.705 UTC  1.0
# 3  2023-07-20 13:01:02.487 UTC  1.0
# 4  2023-07-20 13:01:40.445 UTC  1.0

# %%
pixpersec.rename(columns={'0': 'pixels_per_sec'}, inplace=True)

# %%
pix_per_second_final = pixpersec.groupby('timestamp', as_index=False)['pixels_per_sec'].sum()

# %%
pix_per_second_final
# Out:
#                             timestamp  pixels_per_sec
# 0         2023-07-20 13:00:26.088 UTC             1.0
# 1         2023-07-20 13:00:43.658 UTC             1.0
# 2         2023-07-20 13:00:43.705 UTC             1.0
# 3         2023-07-20 13:01:02.487 UTC             1.0
# 4         2023-07-20 13:01:40.445 UTC             1.0
# ...                               ...             ...
# 77252406  2023-07-25 21:38:35.326 UTC             2.0
# 77252407  2023-07-25 21:38:35.386 UTC             1.0
# 77252408  2023-07-25 21:38:35.512 UTC             1.0
# 77252409  2023-07-25 21:38:35.806 UTC             2.0
# 77252410  2023-07-25 21:38:35.864 UTC             1.0
#
# [77252411 rows x 2 columns]

# %% [markdown]
# # count by color

# %%
countbycolor = onefile(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\county by color')

# %%
countbycolor.head(5)
# Out:
#   pixel_color          0
# 0     #000000  7430971.0
# 1     #00A368  1772123.0
# 2     #3690EA  3901711.0
# 3     #B44AC0  1488675.0
# 4     #FF4500  5435270.0

# %%
countbycolor.rename(columns={'0': 'total_pixels'}, inplace=True)

# %%
count_by_color_final = countbycolor.groupby('pixel_color', as_index=False)['total_pixels'].sum()

# %%
count_by_color_final
# Out:
#    pixel_color  total_pixels
# 0      #000000    28408060.0
# 1      #00756F      275618.0
# 2      #009EAA      145749.0
# 3      #00A368     4875511.0
# 4      #00CC78      444408.0
# 5      #00CCC0       59905.0
# 6      #2450A4     5462481.0
# 7      #3690EA     7314860.0
# 8      #493AC1      397251.0
# 9      #515252      438884.0
# 10     #51E9F4     2300969.0
# 11     #6A5CFF      216133.0
# 12     #6D001A      265459.0
# 13     #6D482F      683935.0
# 14     #7EED56     2055706.0
# 15     #811E9F     1162767.0
# 16     #898D90     2023481.0
# 17     #94B3FF       61491.0
# 18     #9C6926     1764913.0
# 19     #B44AC0     2403666.0
# 20     #BE0039     2563864.0
# 21     #D4D7D9     2579939.0
# 22     #DE107F      182128.0
# 23     #E4ABFF       86778.0
# 24     #FF3881      559008.0
# 25     #FF4500    17750654.0
# 26     #FF99AA     2843540.0
# 27     #FFA800     4856514.0
# 28     #FFB470      410331.0
# 29     #FFD635     9240790.0
# 30     #FFF8B8      292106.0
# ...

# %% [markdown]
# # avg time diff

# %%
timediff = onefile(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\timediff')

# %%
timediff.head(5)
# Out:
#                                                 user           0
# 0  ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...         NaN
# 1  +++9mkCyhbuOFF5ZusNO7JGW63zMmkWVwoqOqM6D9/9rxK...  157.023810
# 2  +++DHgz9FIWS2Ux/9geWfi2uf4+trwOcs2MJlGPw/ZyFkT...   47.133333
# 3  +++DVJPUzMUiQybH5SaWeO15S5jKuyW1AYw0L7HKM9bx4d...         NaN
# 4  +++IG2b8dqn9TcyyJa/ngp9XDr7tjfVX9kraYN4JtQyulv...   41.333333

# %%
timediff.rename(columns={'0': 'avg_time_diff'}, inplace=True)

# %%
timediff_final = timediff.groupby('user', as_index = False)['avg_time_diff'].mean()

# %%
timediff_final
# Out:
#                                                       user  avg_time_diff
# 0        ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...            NaN
# 1        +++2YMNQROwh54UiQEYv6iz5yQdEr8uXrZ2EcTkipRbtJ+...            NaN
# 2        +++2ny7CcancFxNL6HI+hcDiqXGepL+zGk9n9wfz8tNjCA...     116.869444
# 3        +++5DPynrKmnxpZ5nTRQ3tH/bHtaN90XCoL0R8e5a3mLuo...      74.616667
# 4        +++8f06xnBjeWJ3728FQUjrV5mg3eJRHZra2yYWSySguD7...      17.761429
# ...                                                    ...            ...
# 8520735  zzzjfV1HB0gkG+okqEPrPMkX27yhc8p2qv65lYVEXrShF+...            NaN
# 8520736  zzzrqJ2aW2HA7cFdwVYBHBzvVFaY1j8AF8TMBT7NEORdQm...      32.130556
# 8520737  zzztnsHs8wXafNsiw7ldFCrJT2iFdz8/IpP9dTNp3jx+6x...            NaN
# 8520738  zzzx8RjteNN3ctg2wCJKoHujFjipe04ohdyKyLE4rvZWea...      91.373077
# 8520739  zzzyKoWFuXZ5fG46Fr5izLfUAw6H7BTx/by2MvDWEryfO2...            NaN
#
# [8520740 rows x 2 columns]

# %%
df = timediff_final[(timediff_final['avg_time_diff'] == 5)]

# %%
df
# Out:
#                                                       user  avg_time_diff
# 5093     +0RlcwfW6zfWrmNyYwkDMl3XveVlehzaDMvPP4P5+CIa9c...            5.0
# 7107     +1RJBuEcyVIboCr4lWgRjRi6mplDrYJAioZ/8B650dVA0b...            5.0
# 10934    +3I7tqBfWFdu5T91mA72gbs5obFR83xr7Fk8qiCgbw6ISi...            5.0
# 14196    +4ti8OSPg5o7a20C4VbIEzzjtK65qi30gGzkOdbYpXkzxi...            5.0
# 19161    +7KBIcDVbdO4c7W74u9iwMBv8FnyJtErDhhuP6JgRTcHVS...            5.0
# ...                                                    ...            ...
# 8490684  zlVf1QuuHKJXdXVVWiqhP5qHC2piLdTW2WNa0ZqYc81VWO...            5.0
# 8495859  znyIsvMEoUXcmjawR6/EQqoo1GuggddrZYNMOZ9QEXgNcW...            5.0
# 8502339  zr6G+x0uG1f2sm2YZgr1HwHdea7J2f2KTkRa1DVUSbSepD...            5.0
# 8507559  ztcjow776o3v1nTxbjCCnKBrntxcyt8EU+yG7yDjMkqtvf...            5.0
# 8516194  zxmSHxepOoAeHMrQPc2LXEWka9PDKCl3FAnmt2WoP/Svl5...            5.0
#
# [1761 rows x 2 columns]

# %% [markdown]
# # avg var

# %%
vartime = onefile(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\vartime')

# %%
vartime.head(5)
# Out:
#                                                 user           0
# 0  ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...         NaN
# 1  +++9mkCyhbuOFF5ZusNO7JGW63zMmkWVwoqOqM6D9/9rxK...  802.271911
# 2  +++DHgz9FIWS2Ux/9geWfi2uf4+trwOcs2MJlGPw/ZyFkT...         NaN
# 3  +++DVJPUzMUiQybH5SaWeO15S5jKuyW1AYw0L7HKM9bx4d...         NaN
# 4  +++IG2b8dqn9TcyyJa/ngp9XDr7tjfVX9kraYN4JtQyulv...         NaN

# %%
vartime.rename(columns={'0': 'time_var'}, inplace=True)

# %%
vartime_final = vartime.groupby('user', as_index = False)['time_var'].mean()

# %%
vartime_final
# Out:
#                                                       user    time_var
# 0        ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...         NaN
# 1        +++2YMNQROwh54UiQEYv6iz5yQdEr8uXrZ2EcTkipRbtJ+...         NaN
# 2        +++2ny7CcancFxNL6HI+hcDiqXGepL+zGk9n9wfz8tNjCA...  767.947269
# 3        +++5DPynrKmnxpZ5nTRQ3tH/bHtaN90XCoL0R8e5a3mLuo...         NaN
# 4        +++8f06xnBjeWJ3728FQUjrV5mg3eJRHZra2yYWSySguD7...   32.690713
# ...                                                    ...         ...
# 8520735  zzzjfV1HB0gkG+okqEPrPMkX27yhc8p2qv65lYVEXrShF+...         NaN
# 8520736  zzzrqJ2aW2HA7cFdwVYBHBzvVFaY1j8AF8TMBT7NEORdQm...   24.106204
# 8520737  zzztnsHs8wXafNsiw7ldFCrJT2iFdz8/IpP9dTNp3jx+6x...         NaN
# 8520738  zzzx8RjteNN3ctg2wCJKoHujFjipe04ohdyKyLE4rvZWea...  455.059714
# 8520739  zzzyKoWFuXZ5fG46Fr5izLfUAw6H7BTx/by2MvDWEryfO2...         NaN
#
# [8520740 rows x 2 columns]

# %% [markdown]
# # changes per cordinate

# %%
changescord = onefile(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\changes cord')

# %%
changescord
# Out:
#                       coordinate     0
# 0                          -1,-1  65.0
# 1                         -1,-10   3.0
# 2                        -1,-100  12.0
# 3                        -1,-101  17.0
# 4                        -1,-102  10.0
# ...                          ...   ...
# 17213615  {X: 960, Y: 101, R: 3}   1.0
# 17213616  {X: 968, Y: 102, R: 3}   1.0
# 17213617   {X: 97, Y: 103, R: 1}   1.0
# 17213618  {X: 98, Y: -142, R: 1}   1.0
# 17213619   {X: 98, Y: 118, R: 1}   1.0
#
# [17213620 rows x 2 columns]

# %%
changescord.rename(columns={'0': 'number_of_changes'}, inplace=True)

# %%
changed_cord_final = changescord.groupby('coordinate', as_index=False)['number_of_changes'].sum()

# %%
changed_cord_final
# Out:
#                       coordinate  number_of_changes
# 0                          -1,-1              412.0
# 1                         -1,-10               25.0
# 2                        -1,-100               19.0
# 3                       -1,-1000               31.0
# 4                        -1,-101               53.0
# ...                          ...                ...
# 5988815  {X: 995, Y: -777, R: 2}                1.0
# 5988816  {X: 996, Y: -765, R: 2}                1.0
# 5988817  {X: 996, Y: -772, R: 2}                1.0
# 5988818  {X: 997, Y: -747, R: 2}                1.0
# 5988819  {X: 997, Y: -755, R: 2}                1.0
#
# [5988820 rows x 2 columns]

# %% [markdown]
# # user table

# %%
user_df = color_per_user_final
for df in [cord_user_final, unique_cord_user_final, pix_per_user_final, timediff_final, vartime_final]:
    user_df = pd.merge(user_df, df, on='user', how='outer')

# %%
user_df
# Out:
#                                                       user  \
# 0        ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...
# 1        +++2YMNQROwh54UiQEYv6iz5yQdEr8uXrZ2EcTkipRbtJ+...
# 2        +++2ny7CcancFxNL6HI+hcDiqXGepL+zGk9n9wfz8tNjCA...
# 3        +++5DPynrKmnxpZ5nTRQ3tH/bHtaN90XCoL0R8e5a3mLuo...
# 4        +++8f06xnBjeWJ3728FQUjrV5mg3eJRHZra2yYWSySguD7...
# ...                                                    ...
# 8520735  zzzjfV1HB0gkG+okqEPrPMkX27yhc8p2qv65lYVEXrShF+...
# 8520736  zzzrqJ2aW2HA7cFdwVYBHBzvVFaY1j8AF8TMBT7NEORdQm...
# 8520737  zzztnsHs8wXafNsiw7ldFCrJT2iFdz8/IpP9dTNp3jx+6x...
# 8520738  zzzx8RjteNN3ctg2wCJKoHujFjipe04ohdyKyLE4rvZWea...
# 8520739  zzzyKoWFuXZ5fG46Fr5izLfUAw6H7BTx/by2MvDWEryfO2...
#
#                                                     colors  \
# 0        #3690EA#FFA800#000000#000000#898D90#FFFFFF#51E...
# 1                                                  #FF4500
# 2        #000000#FFD635#FF4500#000000#000000#FF4500#000...
# ...

# %%
user_df['id'] = range(1, len(df) + 1)

# Drop the 'user' column
user_df = user_df.drop('user', axis=1)

# %%
user_df['avg_time_diff'].mean()
# Out:
# 31.707145669325715

# %%
user_df['unique_color_count'].median()
# Out:
# 2.0

# %%
user_df.to_csv(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\final_df.csv', index=False)

# %%
changed_cord_final.to_csv(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\changes_cord.csv', index=False)

# %%
count_by_color_final.to_csv(r'C:\Users\Fernando Fonseca\Downloads\Output\Output\count_by_color.csv', index=False)

# %% [markdown]
# # user stats for presentation

# %%
df = pd.read_csv(r"C:\Users\Fernando Fonseca\Downloads\Output\Output\user_df_final.csv")

# %%
df
# Out:
#                                                       user  \
# 0        ++++K56vVwFvtMk4rJYyUfMpRYAIqMKxu6u8ebfFkWPnEG...
# 1        +++2YMNQROwh54UiQEYv6iz5yQdEr8uXrZ2EcTkipRbtJ+...
# 2        +++2ny7CcancFxNL6HI+hcDiqXGepL+zGk9n9wfz8tNjCA...
# 3        +++5DPynrKmnxpZ5nTRQ3tH/bHtaN90XCoL0R8e5a3mLuo...
# 4        +++8f06xnBjeWJ3728FQUjrV5mg3eJRHZra2yYWSySguD7...
# ...                                                    ...
# 8520735  zzzjfV1HB0gkG+okqEPrPMkX27yhc8p2qv65lYVEXrShF+...
# 8520736  zzzrqJ2aW2HA7cFdwVYBHBzvVFaY1j8AF8TMBT7NEORdQm...
# 8520737  zzztnsHs8wXafNsiw7ldFCrJT2iFdz8/IpP9dTNp3jx+6x...
# 8520738  zzzx8RjteNN3ctg2wCJKoHujFjipe04ohdyKyLE4rvZWea...
# 8520739  zzzyKoWFuXZ5fG46Fr5izLfUAw6H7BTx/by2MvDWEryfO2...
#
#                                                     colors  \
# 0        #3690EA#FFA800#000000#000000#898D90#FFFFFF#51E...
# 1                                                  #FF4500
# 2        #000000#FFD635#FF4500#000000#000000#FF4500#000...
# ...

# %%
time_intervals = [4, 5, 6, 7, 8, 9, 10, 20]
filtered_data = user_df[user_df['avg_time_diff'].isin(time_intervals)]

# %%
filtered_data
# Out:
#                                       colors  unique_color_count  \
# 328                                  #FF4500                   1
# 686                                  #FF4500                   1
# 1680                   #FF4500#FF4500#FFFFFF                   2
# 2098                                 #000000                   1
# 2399                          #000000#FF4500                   2
# ...                                      ...                 ...
# 8518228                              #FFD635                   1
# 8518888                #000000#FF4500#FF4500                   2
# 8519764  #7EED56#FF99AA#FF4500#FFD635#FF4500                   4
# 8520479  #FFA800#FF4500#3690EA#3690EA#FFFFFF                   4
# 8520697                       #FF4500#FFB470                   2
#
#                                       coordinates  unique_cord  tot_pixels  \
# 328                                      -293,369          8.0         8.0
# ...

# %%
filtered_data['pixel_category'] = filtered_data['tot_pixels'].apply(lambda x: '10 or More' if x >= 10 else 'Less than 10')

category_counts = filtered_data.groupby(['avg_time_diff', 'pixel_category']).size().unstack()

category_counts.plot(kind='bar', stacked=True)
plt.xlabel('Average Time Between Activities (minutes)')
plt.ylabel('Number of Users')
plt.title('User Count by Time Interval and Pixels Placed')
plt.xticks(rotation=0)
plt.legend(title='Pixels Placed')
plt.show()
# Out:
# C:\Users\Fernando_Fonseca\Desktop\ipykernel_35016\3446189307.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['pixel_category'] = filtered_data['tot_pixels'].apply(lambda x: '10 or More' if x >= 10 else 'Less than 10')
